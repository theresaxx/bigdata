# %% [markdown]
# # MongoDB
#
# Based on https://docs.mongodb.com/getting-started

# %% [markdown]
# MongoDB is a **NoSQL** open-source **document database**.  MongoDB provides horizontal scaling by replicating and partitioning the data over multiple nodes. This can improve the reliability and scalability of the system.
#
# A record in MongoDB is a **document**, which is a data structure composed of field and value pairs. MongoDB documents are similar to JSON objects or Python dictionaries. The values of fields may include other documents, arrays, and arrays of documents.
#
# This is an example of a document:
# ```JSON
# {
#    "_id" : ObjectId("54c955492b7c8eb21818bd09"),
#    "address" : {
#       "street" : "2 Avenue",
#       "zipcode" : "10075",
#       "building" : "1480",
#       "coord" : [ -73.9557413, 40.7720266 ]
#    },
#    "borough" : "Manhattan",
#    "cuisine" : "Italian",
#    "grades" : [
#       {
#          "date" : ISODate("2014-10-01T00:00:00Z"),
#          "grade" : "A",
#          "score" : 11
#       },
#       {
#          "date" : ISODate("2014-01-16T00:00:00Z"),
#          "grade" : "B",
#          "score" : 17
#       }
#    ],
#    "name" : "Vella",
#    "restaurant_id" : "41704620"
# }
# ```
# In MongoDB, documents have a unique **_id** field that acts as a primary key. MongoDB automatically adds a unique _id to each document if you are not providing it by yourself.
#
# MongoDB stores documents in **collections**. Collections are analogous to tables in relational databases. Unlike a table, however, a collection does not require its documents to have the same schema.
#
# You can start a Docker image with MongoDB like this:
# ```bash
# docker run -p 27017:27017 -d mongo
# ```
#
# In production you really (!) would need to enable authentication with username and password, but for development purposes this is fine.

# %%
#Install the pymongo Python Package 
#!pip3 install pymongo

# %%
from pymongo import MongoClient
from pprint import pprint
import requests

# %% [markdown]
# Use MongoClient to create a connection. If you do not specify any arguments to MongoClient, then MongoClient defaults to the MongoDB instance that runs on the localhost interface on port 27017. You can also specify a complete MongoDB URI to define the connection, including explicitly specifying the host and port number. For example, the following creates a connection to a MongoDB instance that runs on mongodb0.example.net and the port of 27017: client = MongoClient("mongodb://mongodb0.example.net:27017")

# %%
# Client connects to "localhost" by default 
client = MongoClient()

# %% [markdown]
# The first fundamental class of objects you will interact with using pymongo is Database which represents the database construct in MongoDB. Databases hold groups of logically related collections. MongoDB creates new databases implicitly upon their first use. Connect (create) with a database of your name, e.g.
#
# ```python
# db = client["rolandmueller"]
# ```
# or
#
# ```python
# db = client.rolandmueller
# ```

# %%
# Create local "bipm" database on the fly 
db = client['bipm']

# %%
# When we rerun the whole notebook, we start from scratch 
# by dropping the colection "courses"
db.courses.drop()

# %%
# Create a Python Dictonary
courses = [
    {'title': 'Data Science',
     'lecturer': {
         'name': 'Markus Löcher',
         'department': 'Math',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Data Warehousing',
     'lecturer': {
         'name': 'Roland M. Mueller',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Business Process Management',
     'lecturer': {
         'name': 'Frank Habermann',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Stratigic Issues of IT',
     'lecturer': {
         'name': 'Sven Pohland',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Text, Web and Social Media Analytics Lab',
     'lecturer': {
         'name': 'Markus Löcher',
         'department': 'Math',
         'status': 'Professor'
     },
     'semester': 2},
    {'title': 'Enterprise Architectures for Big Data',
     'lecturer': {
         'name': 'Roland M. Mueller',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 2},
    {'title': 'Business Process Integration Lab',
     'lecturer': {
         'name': 'Frank Habermann',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 2},
    {'title': 'IT-Security and Privacy',
     'lecturer': {
         'name': 'Dennis Uckel',
         'department': 'Information Systems',
         'status': 'External'
     },
     'semester': 2},
    {'title': 'Research Methods',
     'lecturer': {
         'name': 'Marcus Birkenkrahe',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 2},
]

# %%
pprint(courses)
# Out:
# [{'lecturer': {'department': 'Math',
#                'name': 'Markus Löcher',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Data Science'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Roland M. Mueller',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Data Warehousing'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Frank Habermann',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Business Process Management'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Sven Pohland',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Stratigic Issues of IT'},
#  {'lecturer': {'department': 'Math',
#                'name': 'Markus Löcher',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Text, Web and Social Media Analytics Lab'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Roland M. Mueller',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Enterprise Architectures for Big Data'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Frank Habermann',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Business Process Integration Lab'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Dennis Uckel',
#                'status': 'External'},
#   'semester': 2,
#   'title': 'IT-Security and Privacy'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Marcus Birkenkrahe',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Research Methods'}]

# %% [markdown]
# ## insert_many()
#
# You can use the `insert_one()` method and the `insert_many()` method to add documents to a collection in MongoDB. If you attempt to add documents to a collection that does not exist, MongoDB will create the collection for you.

# %%
db.courses.insert_many(courses)

# %% [markdown]
# ## find()
#
# You can use the find() method to issue a query to retrieve data from a collection in MongoDB. All queries in MongoDB have the scope of a single collection.
# Queries can return all documents in a collection or only the documents that match a specified filter or criteria. You can specify the filter or criteria in a document and pass as a parameter to the find() method. With no parameter, find() returns all documents in the collection.
#
# The find() method returns query results in a cursor, which is an iterable object that yields documents. Then you can print all documents.
#
# ```python
# cursor = db.my_collection.find()
#
# for document in cursor:
#     pprint(document)
# ```

# %%
# TODO: Print all courses
cursor = db.courses.find()

for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb23'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Science'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb24'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Warehousing'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb25'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Business Process Management'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb26'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Sven Pohland',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Stratigic Issues of IT'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb27'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb28'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Enterprise Architectures for Big Data'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2a'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Dennis Uckel',
#               'status': 'External'},
#  'semester': 2,
#  'title': 'IT-Security and Privacy'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2b'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Marcus Birkenkrahe',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Research Methods'}

# %% [markdown]
# ## JSON
#
# You can store a JSON document if you convert it before to a Python dictionary:

# %%
import json

# %%
my_json = '{"title": "Master Thesis", "semester": 3}'
another_course = json.loads(my_json)
another_course
# Out:
# {'title': 'Master Thesis', 'semester': 3}

# %% [markdown]
# ## insert_one()
#
# The `insert_one()` method adds the document into the collection.

# %%
# TODO: Store `another_course` as another course:
db.courses.insert_one({'title': 'another_course'})

# %%
# TODO: Print all courses

cursor = db.courses.find()
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb23'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Science'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb24'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Warehousing'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb25'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Business Process Management'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb26'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Sven Pohland',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Stratigic Issues of IT'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb27'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb28'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Enterprise Architectures for Big Data'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2a'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Dennis Uckel',
#               'status': 'External'},
#  'semester': 2,
#  'title': 'IT-Security and Privacy'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2b'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Marcus Birkenkrahe',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Research Methods'}
# {'_id': ObjectId('6291ee8b4bbe6c274c08cb2c'),
#  'semester': 3,
#  'title': 'Master Thesis'}
# {'_id': ObjectId('6291ef0b4bbe6c274c08cb2d'), 'title': 'another_course'}

# %% [markdown]
# ## find_one() and find()
#
# `find_one()` returns the first match. ```find()```returns all matches.
#
# The query condition for `find_one()` and `find()` for an equality match on fields has the following form:
# ```python
# { <field1>: <value1>, <field2>: <value2>, ... }
# ```
#
# The following operation finds the first documents whose name field equals "Manhattan".
#
# ```python
# cursor = db.restaurants.find_one({"name": "Manhattan"})
# ```

# %%
# TODO: Find the course with the title "Data Science" 
# save the result in a varibale result
# and pprint the result.

result = db.courses.find_one({"title": "Data Science"})
print(result)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb23'), 'title': 'Data Science', 'lecturer': {'name': 'Markus Löcher', 'department': 'Math', 'status': 'Professor'}, 'semester': 1}

# %%
print(result["_id"])
print(result["lecturer"]["name"])
# Out:
# 6291eabd4bbe6c274c08cb23
# Markus Löcher

# %%
# TODO: Find the first course (one course) in the second semester
# and print it
secondsemester = db.courses.find_one({"semester": 2})
print(secondsemester["title"])
# Out:
# Text, Web and Social Media Analytics Lab

# %%
# TODO: Find all courses in the second semester
# and print the course titles
secondsemester_titles = db.courses.find({"semester": 2}, {"title"})
for document in secondsemester_titles:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb27'),
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb28'),
#  'title': 'Enterprise Architectures for Big Data'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'title': 'Business Process Integration Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2a'),
#  'title': 'IT-Security and Privacy'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2b'), 'title': 'Research Methods'}

# %%
# TODO: Find all courses in the second semester
# and print the lecturers names
secondsemester_lecturers = db.courses.find({"semester": 2}, {"lecturer.name"})
for document in secondsemester_lecturers:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb27'),
#  'lecturer': {'name': 'Markus Löcher'}}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb28'),
#  'lecturer': {'name': 'Roland M. Mueller'}}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'lecturer': {'name': 'Frank Habermann'}}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2a'),
#  'lecturer': {'name': 'Dennis Uckel'}}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2b'),
#  'lecturer': {'name': 'Marcus Birkenkrahe'}}

# %% [markdown]
# ## Subelements
#
# Sometimes documents contains embedded documents as its elements. To specify a condition on a field in these documents, use the dot notation. Dot notation requires quotes around the whole dotted field name. The following queries for documents whose grades array contains an embedded document with a field grade equal to "B".
#
# ```python
# cursor = db.restaurants.find({"grades.grade": "B"})
# ```

# %%
# TODO: Find all courses of Frank Habermann
# and print the title and the semester
cursor = db.courses.find({"lecturer.name": "Frank Habermann"}, {"title", "semester"})
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb25'),
#  'semester': 1,
#  'title': 'Business Process Management'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}

# %% [markdown]
# ## Logical AND
#
# You can specify a logical conjunction (AND) for a list of query conditions by separating the conditions with a comma in the conditions document.
#
# ```python
# cursor = db.restaurants.find({"cuisine": "Italian", "address.zipcode": "10075"})
# ```

# %%
# TODO: Find all courses from Frank Habermann in the second semester
# and print the title and the semester
cursor = db.courses.find({"lecturer.name": "Frank Habermann", "semester": 2}, {"title", "semester"})
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}

# %% [markdown]
# ## Logical OR
#
# You can specify a logical disjunction (OR) for a list of query conditions by using the $or query operator.
#
# ```python
# cursor = db.restaurants.find({"$or": [{"cuisine": "Italian"}, {"address.zipcode": "10075"}]})
# ```

# %%
# TODO: Find all courses from Frank Habermann or Markus Löcher
# and print the title and the semester

cursor = db.courses.find({"$or": [{"lecturer.name": "Frank Habermann"}, {"lecturer.name":"Markus Löcher"}]}, {"title", "semester"})
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb23'),
#  'semester': 1,
#  'title': 'Data Science'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb25'),
#  'semester': 1,
#  'title': 'Business Process Management'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb27'),
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}

# %% [markdown]
# ## Greater than, Less than
#
# MongoDB provides operators to specify query conditions, such as comparison operators. Query conditions using operators generally have the following form:
# ```python
# { <field1>: { <operator1>: <value1> } }
# ```
#
# Greater Than Operator (`$gt`). Query for documents whose grades array contains an embedded document with a field score greater than 30.
#
# ```python
# cursor = db.restaurants.find({"grades.score": {"$gt": 30}})
# ```
#
# Less Than Operator (`$lt`). Query for documents whose grades array contains an embedded document with a field score less than 10.
#
# ```python
# cursor = db.restaurants.find({"grades.score": {"$lt": 10}})
# ```

# %%
# TODO: Find all courses in semester greater than 1
# and print the title and the semester

cursor = db.courses.find({"semester": {"$gt": 1}}, {"title", "semester"})
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291eabd4bbe6c274c08cb27'),
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb28'),
#  'semester': 2,
#  'title': 'Enterprise Architectures for Big Data'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb29'),
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2a'),
#  'semester': 2,
#  'title': 'IT-Security and Privacy'}
# {'_id': ObjectId('6291eabd4bbe6c274c08cb2b'),
#  'semester': 2,
#  'title': 'Research Methods'}
# {'_id': ObjectId('6291ee8b4bbe6c274c08cb2c'),
#  'semester': 3,
#  'title': 'Master Thesis'}

# %% [markdown]
# ## Counting
#
# `count_documents()` works like `find()` but returns the number of matched documents-

# %%
# TODO: How many courses are in the second semester?
cursor = db.courses.count_documents({"semester" : 2})
print(cursor)
# Out:
# 5

# %% [markdown]
# # Downloading Nobel Prize Winners with an API and storing them in MongoDB
#
# ![](https://upload.wikimedia.org/wikipedia/en/e/ed/Nobel_Prize.png)
# The Nobel Prize offers a Web API https://nobelprize.readme.io/docs/prize
#
# Because the API is giving us JSON and MongoDB is able to store documents in a JSON-like format, using a document database like MongoDB seems like a good fit to store the results of the API.  You can get all laureates at http://api.nobelprize.org/v1/laureate.json and all prizes at http://api.nobelprize.org/v1/prize.json
#
# We will just download all laureates and prizes and store them in MongoDB!

# %%
# Create local "nobel" database on the fly 
db = client["nobel"]
db.prizes.drop()
db.laureates.drop()
# API documented at https://nobelprize.readme.io/docs/prize 
for collection_name in ["prizes", "laureates"]:
    singular = collection_name[:-1] # the API uses singular
    response = requests.get( "http://api.nobelprize.org/v1/{}.json".format(singular)) 
    documents = response.json()[collection_name] 
    # Create collections on the fly 
    db[collection_name].insert_many(documents)

# %%
pprint(db.laureates.find_one())
# Out:
# {'_id': ObjectId('6291fc274bbe6c274c08cdc0'),
#  'born': '1845-03-27',
#  'bornCity': 'Lennep (now Remscheid)',
#  'bornCountry': 'Prussia (now Germany)',
#  'bornCountryCode': 'DE',
#  'died': '1923-02-10',
#  'diedCity': 'Munich',
#  'diedCountry': 'Germany',
#  'diedCountryCode': 'DE',
#  'firstname': 'Wilhelm Conrad',
#  'gender': 'male',
#  'id': '1',
#  'prizes': [{'affiliations': [{'city': 'Munich',
#                                'country': 'Germany',
#                                'name': 'Munich University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services he '
#                            'has rendered by the discovery of the remarkable '
#                            'rays subsequently named after him"',
#              'share': '1',
#              'year': '1901'}],
#  'surname': 'Röntgen'}

# %%
# TODO: Print the first name of the first document
cursor = db.laureates.find_one({'id': '1'},{"firstname"})
print(cursor)
# Out:
# {'_id': ObjectId('6291fc274bbe6c274c08cdc0'), 'firstname': 'Wilhelm Conrad'}

# %% [markdown]
# With `count_documents` you can count the number of matching documents.

# %%
# How many female laureates exists? 
cursor = db.laureates.count_documents({'gender': 'female'})
print(cursor)
# Out:
# 58

# %% [markdown]
# With the `$regex` function you can use a regular expression. `distinct` list only all distinct entries.

# %%
db.laureates.distinct("bornCountry", {"bornCountry": {"$regex": "Germany"}})
# Out:
# ['Prussia (now Germany)',
#  'Hesse-Kassel (now Germany)',
#  'Germany',
#  'Schleswig (now Germany)',
#  'Germany (now Poland)',
#  'Germany (now France)',
#  'West Germany (now Germany)',
#  'Bavaria (now Germany)',
#  'Germany (now Russia)',
#  'Mecklenburg (now Germany)',
#  'W&uuml;rttemberg (now Germany)',
#  'East Friesland (now Germany)']

# %%
# TODO: How many laureates are from Germany?
print(db.laureates.count_documents({"bornCountry": {"$regex": "Germany"}}))
# Out:
# 97

# %%
# TODO: Find all physics nobel laureates that are from Germany
# print the year of the first prize, the first name, and surename
cursor = db.laureates.find({"bornCountry": {"$regex": "Germany"}}, {"prizes.year","firstname", "surname"})
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291fc274bbe6c274c08cdc0'),
#  'firstname': 'Wilhelm Conrad',
#  'prizes': [{'year': '1901'}],
#  'surname': 'Röntgen'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdcc'),
#  'firstname': 'Ferdinand',
#  'prizes': [{'year': '1909'}],
#  'surname': 'Braun'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdd1'),
#  'firstname': 'Max',
#  'prizes': [{'year': '1914'}],
#  'surname': 'von Laue'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdd5'),
#  'firstname': 'Max',
#  'prizes': [{'year': '1918'}],
#  'surname': 'Planck'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdd6'),
#  'firstname': 'Johannes',
#  'prizes': [{'year': '1919'}],
#  'surname': 'Stark'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdd8'),
#  'firstname': 'Albert',
#  'prizes': [{'year': '1921'}],
#  'surname': 'Einstein'}
# {'_id': ObjectId('6291fc274bbe6c274c08cddc'),
#  'firstname': 'James',
#  'prizes': [{'year': '1925'}],
#  'surname': 'Franck'}
# {'_id': ObjectId('6291fc274bbe6c274c08cddd'),
#  'firstname': 'Gustav',
#  'prizes': [{'year': '1925'}],
#  'surname': 'Hertz'}
# {'_id': ObjectId('6291fc274bbe6c274c08cde4'),
#  'firstname': 'Werner',
#  'prizes': [{'year': '1932'}],
#  'surname': 'Heisenberg'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdee'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1943'}],
#  'surname': 'Stern'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdfb'),
#  'firstname': 'Max',
#  'prizes': [{'year': '1954'}],
#  'surname': 'Born'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdfc'),
#  'firstname': 'Walther',
#  'prizes': [{'year': '1954'}],
#  'surname': 'Bothe'}
# {'_id': ObjectId('6291fc274bbe6c274c08cdfe'),
#  'firstname': 'Polykarp',
#  'prizes': [{'year': '1955'}],
#  'surname': 'Kusch'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce0a'),
#  'firstname': 'Rudolf',
#  'prizes': [{'year': '1961'}],
#  'surname': 'Mössbauer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce0d'),
#  'firstname': 'Maria',
#  'prizes': [{'year': '1963'}],
#  'surname': 'Goeppert Mayer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce0e'),
#  'firstname': 'J. Hans D.',
#  'prizes': [{'year': '1963'}],
#  'surname': 'Jensen'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce15'),
#  'firstname': 'Alfred',
#  'prizes': [{'year': '1966'}],
#  'surname': 'Kastler'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce16'),
#  'firstname': 'Hans',
#  'prizes': [{'year': '1967'}],
#  'surname': 'Bethe'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce2c'),
#  'firstname': 'Arno',
#  'prizes': [{'year': '1978'}],
#  'surname': 'Penzias'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce3c'),
#  'firstname': 'Ernst',
#  'prizes': [{'year': '1986'}],
#  'surname': 'Ruska'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce3d'),
#  'firstname': 'Gerd',
#  'prizes': [{'year': '1986'}],
#  'surname': 'Binnig'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce3f'),
#  'firstname': 'J. Georg',
#  'prizes': [{'year': '1987'}],
#  'surname': 'Bednorz'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce43'),
#  'firstname': 'Jack',
#  'prizes': [{'year': '1988'}],
#  'surname': 'Steinberger'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce45'),
#  'firstname': 'Hans G.',
#  'prizes': [{'year': '1989'}],
#  'surname': 'Dehmelt'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce46'),
#  'firstname': 'Wolfgang',
#  'prizes': [{'year': '1989'}],
#  'surname': 'Paul'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce59'),
#  'firstname': 'Horst L.',
#  'prizes': [{'year': '1998'}],
#  'surname': 'Störmer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce5e'),
#  'firstname': 'Emil',
#  'prizes': [{'year': '1902'}],
#  'surname': 'Fischer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce61'),
#  'firstname': 'Adolf',
#  'prizes': [{'year': '1905'}],
#  'surname': 'von Baeyer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce63'),
#  'firstname': 'Eduard',
#  'prizes': [{'year': '1907'}],
#  'surname': 'Buchner'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce66'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1910'}],
#  'surname': 'Wallach'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce6b'),
#  'firstname': 'Richard',
#  'prizes': [{'year': '1915'}],
#  'surname': 'Willstätter'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce73'),
#  'firstname': 'Heinrich',
#  'prizes': [{'year': '1927'}],
#  'surname': 'Wieland'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce74'),
#  'firstname': 'Adolf',
#  'prizes': [{'year': '1928'}],
#  'surname': 'Windaus'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce76'),
#  'firstname': 'Hans',
#  'prizes': [{'year': '1929'}],
#  'surname': 'von Euler-Chelpin'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce77'),
#  'firstname': 'Hans',
#  'prizes': [{'year': '1930'}],
#  'surname': 'Fischer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce78'),
#  'firstname': 'Carl',
#  'prizes': [{'year': '1931'}],
#  'surname': 'Bosch'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce79'),
#  'firstname': 'Friedrich',
#  'prizes': [{'year': '1931'}],
#  'surname': 'Bergius'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce82'),
#  'firstname': 'Adolf',
#  'prizes': [{'year': '1939'}],
#  'surname': 'Butenandt'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce85'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1944'}],
#  'surname': 'Hahn'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce8d'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1950'}],
#  'surname': 'Diels'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce93'),
#  'firstname': 'Hermann',
#  'prizes': [{'year': '1953'}],
#  'surname': 'Staudinger'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce9f'),
#  'firstname': 'Karl',
#  'prizes': [{'year': '1963'}],
#  'surname': 'Ziegler'}
# {'_id': ObjectId('6291fc274bbe6c274c08cea4'),
#  'firstname': 'Manfred',
#  'prizes': [{'year': '1967'}],
#  'surname': 'Eigen'}
# {'_id': ObjectId('6291fc274bbe6c274c08ceab'),
#  'firstname': 'Gerhard',
#  'prizes': [{'year': '1971'}],
#  'surname': 'Herzberg'}
# {'_id': ObjectId('6291fc274bbe6c274c08ceaf'),
#  'firstname': 'Ernst Otto',
#  'prizes': [{'year': '1973'}],
#  'surname': 'Fischer'}
# {'_id': ObjectId('6291fc274bbe6c274c08ceb8'),
#  'firstname': 'Georg',
#  'prizes': [{'year': '1979'}],
#  'surname': 'Wittig'}
# {'_id': ObjectId('6291fc274bbe6c274c08cec4'),
#  'firstname': 'John C.',
#  'prizes': [{'year': '1986'}],
#  'surname': 'Polanyi'}
# {'_id': ObjectId('6291fc274bbe6c274c08cec8'),
#  'firstname': 'Johann',
#  'prizes': [{'year': '1988'}],
#  'surname': 'Deisenhofer'}
# {'_id': ObjectId('6291fc274bbe6c274c08cec9'),
#  'firstname': 'Robert',
#  'prizes': [{'year': '1988'}],
#  'surname': 'Huber'}
# {'_id': ObjectId('6291fc274bbe6c274c08ceca'),
#  'firstname': 'Hartmut',
#  'prizes': [{'year': '1988'}],
#  'surname': 'Michel'}
# {'_id': ObjectId('6291fc274bbe6c274c08cee3'),
#  'firstname': 'Robert',
#  'prizes': [{'year': '1905'}],
#  'surname': 'Koch'}
# {'_id': ObjectId('6291fc274bbe6c274c08ceea'),
#  'firstname': 'Albrecht',
#  'prizes': [{'year': '1910'}],
#  'surname': 'Kossel'}
# {'_id': ObjectId('6291fc274bbe6c274c08cef2'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1922'}],
#  'surname': 'Meyerhof'}
# {'_id': ObjectId('6291fc274bbe6c274c08cefc'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1931'}],
#  'surname': 'Warburg'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf03'),
#  'firstname': 'Hans',
#  'prizes': [{'year': '1935'}],
#  'surname': 'Spemann'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf05'),
#  'firstname': 'Otto',
#  'prizes': [{'year': '1936'}],
#  'surname': 'Loewi'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf08'),
#  'firstname': 'Gerhard',
#  'prizes': [{'year': '1939'}],
#  'surname': 'Domagk'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf0e'),
#  'firstname': 'Ernst B.',
#  'prizes': [{'year': '1945'}],
#  'surname': 'Chain'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf1c'),
#  'firstname': 'Hans',
#  'prizes': [{'year': '1953'}],
#  'surname': 'Krebs'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf1d'),
#  'firstname': 'Fritz',
#  'prizes': [{'year': '1953'}],
#  'surname': 'Lipmann'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf23'),
#  'firstname': 'Werner',
#  'prizes': [{'year': '1956'}],
#  'surname': 'Forssmann'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf34'),
#  'firstname': 'Konrad',
#  'prizes': [{'year': '1964'}],
#  'surname': 'Bloch'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf35'),
#  'firstname': 'Feodor',
#  'prizes': [{'year': '1964'}],
#  'surname': 'Lynen'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf41'),
#  'firstname': 'Max',
#  'prizes': [{'year': '1969'}],
#  'surname': 'Delbrück'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf44'),
#  'firstname': 'Sir Bernard',
#  'prizes': [{'year': '1970'}],
#  'surname': 'Katz'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf68'),
#  'firstname': 'Georges J.F.',
#  'prizes': [{'year': '1984'}],
#  'surname': 'Köhler'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf76'),
#  'firstname': 'Erwin',
#  'prizes': [{'year': '1991'}],
#  'surname': 'Neher'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf77'),
#  'firstname': 'Bert',
#  'prizes': [{'year': '1991'}],
#  'surname': 'Sakmann'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf7f'),
#  'firstname': 'Christiane',
#  'prizes': [{'year': '1995'}],
#  'surname': 'Nüsslein-Volhard'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf87'),
#  'firstname': 'Günter',
#  'prizes': [{'year': '1999'}],
#  'surname': 'Blobel'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfa4'),
#  'firstname': 'Gustav',
#  'prizes': [{'year': '1926'}],
#  'surname': 'Stresemann'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfa6'),
#  'firstname': 'Ludwig',
#  'prizes': [{'year': '1927'}],
#  'surname': 'Quidde'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfad'),
#  'firstname': 'Carl',
#  'prizes': [{'year': '1935'}],
#  'surname': 'von Ossietzky'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfb9'),
#  'firstname': 'Albert',
#  'prizes': [{'year': '1952'}],
#  'surname': 'Schweitzer'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfc7'),
#  'firstname': 'Willy',
#  'prizes': [{'year': '1971'}],
#  'surname': 'Brandt'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfc8'),
#  'firstname': 'Henry',
#  'prizes': [{'year': '1973'}],
#  'surname': 'Kissinger'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfef'),
#  'firstname': 'Theodor',
#  'prizes': [{'year': '1902'}],
#  'surname': 'Mommsen'}
# {'_id': ObjectId('6291fc274bbe6c274c08cff6'),
#  'firstname': 'Rudolf',
#  'prizes': [{'year': '1908'}],
#  'surname': 'Eucken'}
# {'_id': ObjectId('6291fc274bbe6c274c08cff8'),
#  'firstname': 'Paul',
#  'prizes': [{'year': '1910'}],
#  'surname': 'Heyse'}
# {'_id': ObjectId('6291fc274bbe6c274c08d00a'),
#  'firstname': 'Thomas',
#  'prizes': [{'year': '1929'}],
#  'surname': 'Mann'}
# {'_id': ObjectId('6291fc274bbe6c274c08d016'),
#  'firstname': 'Hermann',
#  'prizes': [{'year': '1946'}],
#  'surname': 'Hesse'}
# {'_id': ObjectId('6291fc274bbe6c274c08d02b'),
#  'firstname': 'Nelly',
#  'prizes': [{'year': '1966'}],
#  'surname': 'Sachs'}
# {'_id': ObjectId('6291fc274bbe6c274c08d031'),
#  'firstname': 'Heinrich',
#  'prizes': [{'year': '1972'}],
#  'surname': 'Böll'}
# {'_id': ObjectId('6291fc274bbe6c274c08d072'),
#  'firstname': 'Reinhard',
#  'prizes': [{'year': '1994'}],
#  'surname': 'Selten'}
# {'_id': ObjectId('6291fc274bbe6c274c08d080'),
#  'firstname': 'Herbert',
#  'prizes': [{'year': '2000'}],
#  'surname': 'Kroemer'}
# {'_id': ObjectId('6291fc274bbe6c274c08d08c'),
#  'firstname': 'Wolfgang',
#  'prizes': [{'year': '2001'}],
#  'surname': 'Ketterle'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0bf'),
#  'firstname': 'Theodor W.',
#  'prizes': [{'year': '2005'}],
#  'surname': 'Hänsch'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0c5'),
#  'firstname': 'Robert J.',
#  'prizes': [{'year': '2005'}],
#  'surname': 'Aumann'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0d6'),
#  'firstname': 'Gerhard',
#  'prizes': [{'year': '2007'}],
#  'surname': 'Ertl'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0dd'),
#  'firstname': 'Harald',
#  'prizes': [{'year': '2008'}],
#  'surname': 'zur Hausen'}
# {'_id': ObjectId('6291fc274bbe6c274c08d11a'),
#  'firstname': 'Thomas C.',
#  'prizes': [{'year': '2013'}],
#  'surname': 'Südhof'}
# {'_id': ObjectId('6291fc274bbe6c274c08d14b'),
#  'firstname': 'Rainer',
#  'prizes': [{'year': '2017'}],
#  'surname': 'Weiss'}
# {'_id': ObjectId('6291fc274bbe6c274c08d14f'),
#  'firstname': 'Joachim',
#  'prizes': [{'year': '2017'}],
#  'surname': 'Frank'}
# {'_id': ObjectId('6291fc274bbe6c274c08d166'),
#  'firstname': 'John',
#  'prizes': [{'year': '2019'}],
#  'surname': 'Goodenough'}
# {'_id': ObjectId('6291fc274bbe6c274c08d173'),
#  'firstname': 'Reinhard',
#  'prizes': [{'year': '2020'}],
#  'surname': 'Genzel'}
# {'_id': ObjectId('6291fc274bbe6c274c08d17e'),
#  'firstname': 'Klaus',
#  'prizes': [{'year': '2021'}],
#  'surname': 'Hasselmann'}
# {'_id': ObjectId('6291fc274bbe6c274c08d180'),
#  'firstname': 'Benjamin',
#  'prizes': [{'year': '2021'}],
#  'surname': 'List'}

# %%
# TODO: find and print the document for "Malala" (firstname)
cursor = db.laureates.find({"firstname": {"$regex": "Malala"}})
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291fc274bbe6c274c08d130'),
#  'born': '1997-07-12',
#  'bornCity': 'Mingora',
#  'bornCountry': 'Pakistan',
#  'bornCountryCode': 'PK',
#  'died': '0000-00-00',
#  'firstname': 'Malala',
#  'gender': 'female',
#  'id': '914',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their struggle against the suppression of '
#                            'children and young people and for the right of all '
#                            'children to education"',
#              'share': '2',
#              'year': '2014'}],
#  'surname': 'Yousafzai'}

# %% [markdown]
# ## Sort()
#
# With `sort()` you can sort the list of documents. The parameter of sort is a list of sorting tuples. Each tuple is a value and an integer value 1 or -1 which states whether the collection to be sorted in ascending (1) or descending (-1) order.
#
# Sort all restaurants according to the grade in ascending order.
# ```python
# cursor = db.restaurants.find().sort([("grades.grade", 1)])
# ```

# %%
# TODO: Find only female nobel laureates 
# and sort them according the the prize year in ascending order
# print year of the first prize, firstname, and surename
cursor = db.laureates.find({"gender":"female"}, {"prizes.year","firstname","surname"}).sort([("prizes.year",1)])
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('6291fc274bbe6c274c08cdc5'),
#  'firstname': 'Marie',
#  'prizes': [{'year': '1903'}, {'year': '1911'}],
#  'surname': 'Curie'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf8e'),
#  'firstname': 'Bertha',
#  'prizes': [{'year': '1905'}],
#  'surname': 'von Suttner'}
# {'_id': ObjectId('6291fc274bbe6c274c08cff7'),
#  'firstname': 'Selma',
#  'prizes': [{'year': '1909'}],
#  'surname': 'Lagerlöf'}
# {'_id': ObjectId('6291fc274bbe6c274c08d007'),
#  'firstname': 'Grazia',
#  'prizes': [{'year': '1926'}],
#  'surname': 'Deledda'}
# {'_id': ObjectId('6291fc274bbe6c274c08d009'),
#  'firstname': 'Sigrid',
#  'prizes': [{'year': '1928'}],
#  'surname': 'Undset'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfa9'),
#  'firstname': 'Jane',
#  'prizes': [{'year': '1931'}],
#  'surname': 'Addams'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce7d'),
#  'firstname': 'Irène',
#  'prizes': [{'year': '1935'}],
#  'surname': 'Joliot-Curie'}
# {'_id': ObjectId('6291fc274bbe6c274c08d012'),
#  'firstname': 'Pearl',
#  'prizes': [{'year': '1938'}],
#  'surname': 'Buck'}
# {'_id': ObjectId('6291fc274bbe6c274c08d015'),
#  'firstname': 'Gabriela',
#  'prizes': [{'year': '1945'}],
#  'surname': 'Mistral'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfb2'),
#  'firstname': 'Emily Greene',
#  'prizes': [{'year': '1946'}],
#  'surname': 'Balch'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf12'),
#  'firstname': 'Gerty',
#  'prizes': [{'year': '1947'}],
#  'surname': 'Cori'}
# {'_id': ObjectId('6291fc274bbe6c274c08ce0d'),
#  'firstname': 'Maria',
#  'prizes': [{'year': '1963'}],
#  'surname': 'Goeppert Mayer'}
# {'_id': ObjectId('6291fc274bbe6c274c08cea1'),
#  'firstname': 'Dorothy Crowfoot',
#  'prizes': [{'year': '1964'}],
#  'surname': 'Hodgkin'}
# {'_id': ObjectId('6291fc274bbe6c274c08d02b'),
#  'firstname': 'Nelly',
#  'prizes': [{'year': '1966'}],
#  'surname': 'Sachs'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfcd'),
#  'firstname': 'Betty',
#  'prizes': [{'year': '1976'}],
#  'surname': 'Williams'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfce'),
#  'firstname': 'Mairead',
#  'prizes': [{'year': '1976'}],
#  'surname': 'Corrigan'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf57'),
#  'firstname': 'Rosalyn',
#  'prizes': [{'year': '1977'}],
#  'surname': 'Yalow'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfd2'),
#  'firstname': 'Anjezë Gonxhe',
#  'prizes': [{'year': '1979'}],
#  'surname': 'Bojaxhiu'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfd4'),
#  'firstname': 'Alva',
#  'prizes': [{'year': '1982'}],
#  'surname': 'Myrdal'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf66'),
#  'firstname': 'Barbara',
#  'prizes': [{'year': '1983'}],
#  'surname': 'McClintock'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf6d'),
#  'firstname': 'Rita',
#  'prizes': [{'year': '1986'}],
#  'surname': 'Levi-Montalcini'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf70'),
#  'firstname': 'Gertrude B.',
#  'prizes': [{'year': '1988'}],
#  'surname': 'Elion'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfde'),
#  'firstname': 'Aung San Suu Kyi',
#  'prizes': [{'year': '1991'}]}
# {'_id': ObjectId('6291fc274bbe6c274c08d045'),
#  'firstname': 'Nadine',
#  'prizes': [{'year': '1991'}],
#  'surname': 'Gordimer'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfdf'),
#  'firstname': 'Rigoberta',
#  'prizes': [{'year': '1992'}],
#  'surname': 'Menchú Tum'}
# {'_id': ObjectId('6291fc274bbe6c274c08d047'),
#  'firstname': 'Toni',
#  'prizes': [{'year': '1993'}],
#  'surname': 'Morrison'}
# {'_id': ObjectId('6291fc274bbe6c274c08cf7f'),
#  'firstname': 'Christiane',
#  'prizes': [{'year': '1995'}],
#  'surname': 'Nüsslein-Volhard'}
# {'_id': ObjectId('6291fc274bbe6c274c08d04a'),
#  'firstname': 'Wislawa',
#  'prizes': [{'year': '1996'}],
#  'surname': 'Szymborska'}
# {'_id': ObjectId('6291fc274bbe6c274c08cfea'),
#  'firstname': 'Jody',
#  'prizes': [{'year': '1997'}],
#  'surname': 'Williams'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0ae'),
#  'firstname': 'Shirin',
#  'prizes': [{'year': '2003'}],
#  'surname': 'Ebadi'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0b0'),
#  'firstname': 'Linda B.',
#  'prizes': [{'year': '2004'}],
#  'surname': 'Buck'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0b7'),
#  'firstname': 'Elfriede',
#  'prizes': [{'year': '2004'}],
#  'surname': 'Jelinek'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0b8'),
#  'firstname': 'Wangari',
#  'prizes': [{'year': '2004'}],
#  'surname': 'Maathai'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0d7'),
#  'firstname': 'Doris',
#  'prizes': [{'year': '2007'}],
#  'surname': 'Lessing'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0de'),
#  'firstname': 'Françoise',
#  'prizes': [{'year': '2008'}],
#  'surname': 'Barré-Sinoussi'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0e9'),
#  'firstname': 'Elizabeth H.',
#  'prizes': [{'year': '2009'}],
#  'surname': 'Blackburn'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0ea'),
#  'firstname': 'Carol W.',
#  'prizes': [{'year': '2009'}],
#  'surname': 'Greider'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0f1'),
#  'firstname': 'Ada E.',
#  'prizes': [{'year': '2009'}],
#  'surname': 'Yonath'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0f2'),
#  'firstname': 'Herta',
#  'prizes': [{'year': '2009'}],
#  'surname': 'Müller'}
# {'_id': ObjectId('6291fc274bbe6c274c08d0f4'),
#  'firstname': 'Elinor',
#  'prizes': [{'year': '2009'}],
#  'surname': 'Ostrom'}
# {'_id': ObjectId('6291fc274bbe6c274c08d109'),
#  'firstname': 'Ellen',
#  'prizes': [{'year': '2011'}],
#  'surname': 'Johnson Sirleaf'}
# {'_id': ObjectId('6291fc274bbe6c274c08d10a'),
#  'firstname': 'Leymah',
#  'prizes': [{'year': '2011'}],
#  'surname': 'Gbowee'}
# {'_id': ObjectId('6291fc274bbe6c274c08d10b'),
#  'firstname': 'Tawakkol',
#  'prizes': [{'year': '2011'}],
#  'surname': 'Karman'}
# {'_id': ObjectId('6291fc274bbe6c274c08d120'),
#  'firstname': 'Alice',
#  'prizes': [{'year': '2013'}],
#  'surname': 'Munro'}
# {'_id': ObjectId('6291fc274bbe6c274c08d126'),
#  'firstname': 'May-Britt',
#  'prizes': [{'year': '2014'}],
#  'surname': 'Moser'}
# {'_id': ObjectId('6291fc274bbe6c274c08d130'),
#  'firstname': 'Malala',
#  'prizes': [{'year': '2014'}],
#  'surname': 'Yousafzai'}
# {'_id': ObjectId('6291fc274bbe6c274c08d134'),
#  'firstname': 'Youyou',
#  'prizes': [{'year': '2015'}],
#  'surname': 'Tu'}
# {'_id': ObjectId('6291fc274bbe6c274c08d13a'),
#  'firstname': 'Svetlana',
#  'prizes': [{'year': '2015'}],
#  'surname': 'Alexievich'}
# {'_id': ObjectId('6291fc274bbe6c274c08d158'),
#  'firstname': 'Donna',
#  'prizes': [{'year': '2018'}],
#  'surname': 'Strickland'}
# {'_id': ObjectId('6291fc274bbe6c274c08d159'),
#  'firstname': 'Frances H.',
#  'prizes': [{'year': '2018'}],
#  'surname': 'Arnold'}
# {'_id': ObjectId('6291fc274bbe6c274c08d15d'),
#  'firstname': 'Nadia',
#  'prizes': [{'year': '2018'}],
#  'surname': 'Murad'}
# {'_id': ObjectId('6291fc274bbe6c274c08d169'),
#  'firstname': 'Olga',
#  'prizes': [{'year': '2018'}],
#  'surname': 'Tokarczuk'}
# {'_id': ObjectId('6291fc274bbe6c274c08d16d'),
#  'firstname': 'Esther',
#  'prizes': [{'year': '2019'}],
#  'surname': 'Duflo'}
# {'_id': ObjectId('6291fc274bbe6c274c08d174'),
#  'firstname': 'Andrea',
#  'prizes': [{'year': '2020'}],
#  'surname': 'Ghez'}
# {'_id': ObjectId('6291fc274bbe6c274c08d175'),
#  'firstname': 'Emmanuelle',
#  'prizes': [{'year': '2020'}],
#  'surname': 'Charpentier'}
# {'_id': ObjectId('6291fc274bbe6c274c08d176'),
#  'firstname': 'Jennifer A.',
#  'prizes': [{'year': '2020'}],
#  'surname': 'Doudna'}
# {'_id': ObjectId('6291fc274bbe6c274c08d177'),
#  'firstname': 'Louise',
#  'prizes': [{'year': '2020'}],
#  'surname': 'Glück'}
# {'_id': ObjectId('6291fc274bbe6c274c08d183'),
#  'firstname': 'Maria',
#  'prizes': [{'year': '2021'}],
#  'surname': 'Ressa'}
